# %%
import pandas as pd

# %%
df= pd.read_csv("parking_dataset.csv")

# %%
df.describe()
# Out:
#               hour      weekday       lot_id  class_density        event  \
# count  1440.000000  1440.000000  1440.000000    1440.000000  1440.000000
# mean     11.500000     2.583333     2.000000       3.677083     0.166667
# std       6.924591     1.847185     1.414705       3.798691     0.372807
# min       0.000000     0.000000     0.000000       0.000000     0.000000
# 25%       5.750000     1.000000     1.000000       0.000000     0.000000
# 50%      11.500000     2.500000     2.000000       2.000000     0.000000
# 75%      17.250000     4.000000     3.000000       8.000000     0.000000
# max      23.000000     6.000000     4.000000      10.000000     1.000000
#
#        occupancy_pct
# count    1440.000000
# mean        0.347654
# std         0.318845
# min         0.000000
# 25%         0.060675
# 50%         0.229400
# 75%         0.623775
# max         1.000000
